# %%
import pandas as pd # for data wrangling purpose
import numpy as np # Basic computation library
import seaborn as sns # For Visualization 
import matplotlib.pyplot as plt # ploting package
# %matplotlib inline
import warnings # Filtering warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Temperature%20Forecast/temperature.csv")

# %%
df.head()
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  30-06-2013          28.7          21.4    58.255688    91.116364
# 1      2.0  30-06-2013          31.9          21.6    52.263397    90.604721
# 2      3.0  30-06-2013          31.6          23.3    48.690479    83.973587
# 3      4.0  30-06-2013          32.0          23.4    58.239788    96.483688
# 4      5.0  30-06-2013          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
#    LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM   Slope  \
# 0         0.0         0.0  37.6046  126.991  212.3350  2.7850
# 1         0.0         0.0  37.6046  127.032   44.7624  0.5141
# 2         0.0         0.0  37.5776  127.058   33.3068  0.2661
# 3         0.0         0.0  37.6450  127.022   45.7160  2.5348
# 4         0.0         0.0  37.5507  127.135   35.0380  0.5055
#
#    Solar radiation  Next_Tmax  Next_Tmin
# 0      5992.895996       29.1       21.2
# 1      5869.312500       30.5       22.5
# 2      5863.555664       31.1       23.9
# 3      5856.964844       31.7       24.3
# 4      5859.552246       31.2       22.5
#
# [5 rows x 25 columns]

# %%
df
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# 1       90.604721         29.850689         24.035009   5.691890   51.937448
# 2       83.973587         30.091292         24.565633   6.138224   20.573050
# 3       96.483688         29.704629         23.326177   5.650050   65.727144
# 4       90.155128         29.113934         23.486480   5.735004  107.965535
# ...           ...               ...               ...        ...         ...
# 7747    78.869858         26.352081         18.775678   6.148918   72.058294
# 7748    77.294975         27.010193         18.733519   6.542819   47.241457
# 7749    77.243744         27.939516         18.522965   7.289264    9.090034
# 7750    58.936283         17.624954         14.272646   2.882580  -13.603212
# 7751   100.000153         38.542255         29.619342  21.857621  213.414006
#
#       ...  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM  \
# 0     ...    0.000000    0.000000    0.000000  37.6046  126.991  212.3350
# 1     ...    0.000000    0.000000    0.000000  37.6046  127.032   44.7624
# 2     ...    0.000000    0.000000    0.000000  37.5776  127.058   33.3068
# 3     ...    0.000000    0.000000    0.000000  37.6450  127.022   45.7160
# 4     ...    0.000000    0.000000    0.000000  37.5507  127.135   35.0380
# ...   ...         ...         ...         ...      ...      ...       ...
# 7747  ...    0.000000    0.000000    0.000000  37.5372  126.891   15.5876
# 7748  ...    0.000000    0.000000    0.000000  37.5237  126.909   17.2956
# 7749  ...    0.000000    0.000000    0.000000  37.5237  126.970   19.5844
# 7750  ...    0.000000    0.000000    0.000000  37.4562  126.826   12.3700
# 7751  ...   21.621661   15.841235   16.655469  37.6450  127.135  212.3350
#
#          Slope  Solar radiation  Next_Tmax  Next_Tmin
# 0     2.785000      5992.895996       29.1       21.2
# 1     0.514100      5869.312500       30.5       22.5
# 2     0.266100      5863.555664       31.1       23.9
# 3     2.534800      5856.964844       31.7       24.3
# 4     0.505500      5859.552246       31.2       22.5
# ...        ...              ...        ...        ...
# 7747  0.155400      4443.313965       28.3       18.1
# 7748  0.222300      4438.373535       28.6       18.8
# 7749  0.271300      4451.345215       27.8       17.4
# 7750  0.098475      4329.520508       17.4       11.3
# 7751  5.178230      5992.895996       38.9       29.8
#
# [7752 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Date              7750 non-null   object
#  2   Present_Tmax      7682 non-null   float64
#  3   Present_Tmin      7682 non-null   float64
#  4   LDAPS_RHmin       7677 non-null   float64
#  5   LDAPS_RHmax       7677 non-null   float64
#  6   LDAPS_Tmax_lapse  7677 non-null   float64
#  7   LDAPS_Tmin_lapse  7677 non-null   float64
#  8   LDAPS_WS          7677 non-null   float64
#  9   LDAPS_LH          7677 non-null   float64
#  10  LDAPS_CC1         7677 non-null   float64
#  11  LDAPS_CC2         7677 non-null   float64
#  12  LDAPS_CC3         7677 non-null   float64
#  13  LDAPS_CC4         7677 non-null   float64
#  14  LDAPS_PPT1        7677 non-null   float64
#  15  LDAPS_PPT2        7677 non-null   float64
#  16  LDAPS_PPT3        7677 non-null   float64
#  17  LDAPS_PPT4        7677 non-null   float64
#  18  lat               7752 non-null   float64
#  19  lon               7752 non-null   float64
#  20  DEM               7752 non-null   float64
#  21  Slope             7752 non-null   float64
#  22  Solar radiation   7752 non-null   float64
#  23  Next_Tmax         7725 non-null   float64
#  24  Next_Tmin         7725 non-null   float64
# dtypes: float64(24), object(1)
# memory usage: 1.5+ MB

# %%
# convert date column from object to date type
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Date              7750 non-null   datetime64[ns]
#  2   Present_Tmax      7682 non-null   float64
#  3   Present_Tmin      7682 non-null   float64
#  4   LDAPS_RHmin       7677 non-null   float64
#  5   LDAPS_RHmax       7677 non-null   float64
#  6   LDAPS_Tmax_lapse  7677 non-null   float64
#  7   LDAPS_Tmin_lapse  7677 non-null   float64
#  8   LDAPS_WS          7677 non-null   float64
#  9   LDAPS_LH          7677 non-null   float64
#  10  LDAPS_CC1         7677 non-null   float64
#  11  LDAPS_CC2         7677 non-null   float64
#  12  LDAPS_CC3         7677 non-null   float64
#  13  LDAPS_CC4         7677 non-null   float64
#  14  LDAPS_PPT1        7677 non-null   float64
#  15  LDAPS_PPT2        7677 non-null   float64
#  16  LDAPS_PPT3        7677 non-null   float64
#  17  LDAPS_PPT4        7677 non-null   float64
#  18  lat               7752 non-null   float64
#  19  lon               7752 non-null   float64
#  20  DEM               7752 non-null   float64
#  21  Slope             7752 non-null   float64
#  22  Solar radiation   7752 non-null   float64
#  23  Next_Tmax         7725 non-null   float64
#  24  Next_Tmin         7725 non-null   float64
# dtypes: datetime64[ns](1), float64(24)
# memory usage: 1.5 MB

# %%
#sort data by date
df = df.sort_values('Date')

# %%
df
# Out:
#       station       Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0 2013-06-30          28.7          21.4    58.255688
# 24       25.0 2013-06-30          32.5          24.2    50.274609
# 23       24.0 2013-06-30          31.5          25.0    52.072784
# 22       23.0 2013-06-30          32.7          24.4    54.705585
# 21       22.0 2013-06-30          32.2          23.9    54.512455
# ...       ...        ...           ...           ...          ...
# 7748     24.0 2017-08-30          23.3          17.7    24.040634
# 7736     12.0 2017-08-30          23.8          15.4    25.464573
# 7749     25.0 2017-08-30          23.2          17.4    22.933014
# 7750      NaN        NaT          20.0          11.3    19.794666
# 7751      NaN        NaT          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# 24      75.525017         29.963753         24.972864   6.265457   23.342176
# 23      73.693947         29.344252         24.856806   6.222672   49.007520
# 22      75.919823         28.857981         24.733711   6.019616   90.838489
# 21      88.524696         29.188870         23.801352   6.020390   88.078209
# ...           ...               ...               ...        ...         ...
# 7748    77.294975         27.010193         18.733519   6.542819   47.241457
# 7736    78.012566         26.860758         17.560685   7.411646   19.791088
# 7749    77.243744         27.939516         18.522965   7.289264    9.090034
# 7750    58.936283         17.624954         14.272646   2.882580  -13.603212
# 7751   100.000153         38.542255         29.619342  21.857621  213.414006
#
#       ...  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM  \
# 0     ...    0.000000    0.000000    0.000000  37.6046  126.991  212.3350
# 24    ...    0.000000    0.000000    0.000000  37.5237  126.970   19.5844
# 23    ...    0.000000    0.000000    0.000000  37.5237  126.909   17.2956
# 22    ...    0.000000    0.000000    0.000000  37.5372  126.891   15.5876
# 21    ...    0.000000    0.000000    0.000000  37.5102  127.086   21.9668
# ...   ...         ...         ...         ...      ...      ...       ...
# 7748  ...    0.000000    0.000000    0.000000  37.5237  126.909   17.2956
# 7736  ...    0.000000    0.000000    0.000000  37.5507  126.988  132.1180
# 7749  ...    0.000000    0.000000    0.000000  37.5237  126.970   19.5844
# 7750  ...    0.000000    0.000000    0.000000  37.4562  126.826   12.3700
# 7751  ...   21.621661   15.841235   16.655469  37.6450  127.135  212.3350
#
#          Slope  Solar radiation  Next_Tmax  Next_Tmin
# 0     2.785000      5992.895996       29.1       21.2
# 24    0.271300      5855.093750       32.0       24.2
# 23    0.222300      5850.358887       31.3       23.7
# 22    0.155400      5851.387695       31.8       23.2
# 21    0.133200      5852.904297       32.6       23.7
# ...        ...              ...        ...        ...
# 7748  0.222300      4438.373535       28.6       18.8
# 7736  0.593100      4503.517578       25.8       16.5
# 7749  0.271300      4451.345215       27.8       17.4
# 7750  0.098475      4329.520508       17.4       11.3
# 7751  5.178230      5992.895996       38.9       29.8
#
# [7752 rows x 25 columns]

# %%
#Check missing values
print(df.isnull().sum())
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
#drop null values
print("We had {} Rows and {} Columns before dropping null values.".format(df.shape[0], df.shape[1]))
df.dropna(inplace=True)
print("We have {} Rows and {} Columns after dropping null values.".format(df.shape[0], df.shape[1]))
# Out:
# We had 7752 Rows and 25 Columns before dropping null values.
# We have 7588 Rows and 25 Columns after dropping null values.

# %%
df.isna().sum()
# Out:
# station             0
# Date                0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %%
#we dont have any null values now

# %%
# Converting Date datatypes and spliting date into date, month and year.
#df['Date']=pd.to_datetime(df['Date'])
df['Day']=df['Date'].apply(lambda x:x.day)
df['Month']=df['Date'].apply(lambda x:x.month)
df['Year']=df['Date'].apply(lambda x:x.year)
df.head()
# Out:
#     station       Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0       1.0 2013-06-30          28.7          21.4    58.255688    91.116364
# 24     25.0 2013-06-30          32.5          24.2    50.274609    75.525017
# 23     24.0 2013-06-30          31.5          25.0    52.072784    73.693947
# 22     23.0 2013-06-30          32.7          24.4    54.705585    75.919823
# 21     22.0 2013-06-30          32.2          23.9    54.512455    88.524696
#
#     LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS   LDAPS_LH  ...      lat  \
# 0          28.074101         23.006936  6.818887  69.451805  ...  37.6046
# 24         29.963753         24.972864  6.265457  23.342176  ...  37.5237
# 23         29.344252         24.856806  6.222672  49.007520  ...  37.5237
# 22         28.857981         24.733711  6.019616  90.838489  ...  37.5372
# 21         29.188870         23.801352  6.020390  88.078209  ...  37.5102
#
#         lon       DEM   Slope  Solar radiation  Next_Tmax  Next_Tmin  Day  \
# 0   126.991  212.3350  2.7850      5992.895996       29.1       21.2   30
# 24  126.970   19.5844  0.2713      5855.093750       32.0       24.2   30
# 23  126.909   17.2956  0.2223      5850.358887       31.3       23.7   30
# 22  126.891   15.5876  0.1554      5851.387695       31.8       23.2   30
# 21  127.086   21.9668  0.1332      5852.904297       32.6       23.7   30
#
#     Month  Year
# 0       6  2013
# 24      6  2013
# 23      6  2013
# 22      6  2013
# 21      6  2013
#
# [5 rows x 28 columns]

# %%
df.describe()
# Out:
#            station                           Date  Present_Tmax  Present_Tmin  \
# count  7588.000000                           7588   7588.000000   7588.000000
# mean     13.014101  2015-07-27 18:22:12.208750592     29.748366     23.195809
# min       1.000000            2013-06-30 00:00:00     20.000000     11.300000
# 25%       7.000000            2014-07-15 00:00:00     27.800000     21.600000
# 50%      13.000000            2015-07-29 00:00:00     29.900000     23.400000
# 75%      19.000000            2016-08-14 00:00:00     32.000000     24.800000
# max      25.000000            2017-08-30 00:00:00     37.600000     29.900000
# std       7.217858                            NaN      2.967401      2.400880
#
#        LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  \
# count  7588.000000  7588.000000       7588.000000       7588.000000
# mean     56.724969    88.360823         29.620128         23.511786
# min      19.794666    58.936283         17.624954         14.272646
# 25%      45.960243    84.203724         27.673756         22.086820
# 50%      55.023199    89.784122         29.709537         23.758249
# 75%      67.115099    93.742725         31.711109         25.155660
# max      98.524734   100.000153         38.542255         29.619342
# std      14.626559     7.199456          2.943496          2.342579
#
#           LDAPS_WS     LDAPS_LH  ...          lat         lon          DEM  \
# count  7588.000000  7588.000000  ...  7588.000000  7588.00000  7588.000000
# mean      7.094097    62.492606  ...    37.544792   126.99142    61.918136
# min       2.882580   -13.603212  ...    37.456200   126.82600    12.370000
# 25%       5.675358    37.206201  ...    37.510200   126.93700    28.700000
# 50%       6.547838    56.898324  ...    37.550700   126.99500    45.716000
# 75%       8.028960    84.235666  ...    37.577600   127.04200    59.832400
# max      21.857621   213.414006  ...    37.645000   127.13500   212.335000
# std       2.177034    33.686158  ...     0.050428     0.07922    54.323529
#
#              Slope  Solar radiation    Next_Tmax    Next_Tmin          Day  \
# count  7588.000000      7588.000000  7588.000000  7588.000000  7588.000000
# mean      1.259755      5343.724208    30.241526    22.910820    15.939510
# min       0.098500      4329.520508    17.400000    11.300000     1.000000
# 25%       0.271300      5001.485717    28.200000    21.300000     8.000000
# 50%       0.618000      5441.987305    30.400000    23.100000    16.000000
# 75%       1.767800      5729.485840    32.600000    24.600000    24.000000
# max       5.178200      5992.895996    38.900000    29.800000    31.000000
# std       1.372748       429.782561     3.111807     2.482256     8.906521
#
#              Month         Year
# count  7588.000000  7588.000000
# mean      7.465999  2014.991697
# min       6.000000  2013.000000
# 25%       7.000000  2014.000000
# 50%       7.000000  2015.000000
# 75%       8.000000  2016.000000
# max       8.000000  2017.000000
# std       0.528635     1.410877
#
# [8 rows x 28 columns]

# %%
#visualization
# Plotting histogram for present_Tmax and present_Tmin variables
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(df['Present_Tmax'],kde=True,color='r')
plt.subplot(1,2,2)
sns.histplot(df['Present_Tmin'],kde=True,color='m')
plt.show()

# %%
#Exploration of Target Variable
# Plotting histogram for target variables
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(df['Next_Tmax'],kde=True,color='b')
plt.subplot(1,2,2)
sns.histplot(df['Next_Tmin'],kde=True,color='r')
plt.show()

# %%
#Encoding categorical data
# Sort columns by datatypes
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {float64: ['station', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin', 'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS', 'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4', 'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon', 'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin'], datetime64[ns]: ['Date'], int64: ['Day', 'Month', 'Year']}

# %%
print('Present Maximum Temperature Maxima in year 2013-2016 :',df.Present_Tmax.max())
print('Present Maximum Temperature Minima in year 2013-2016 :',df.Present_Tmax.min())
print(' Average Present Maximum Temperature in year 2013-2016 :',df.Present_Tmax.mean())
print('='*100)
print('Present Minimum Temperature Maxima in year 2013-2016 :',df.Present_Tmin.max())
print('Present Minimum Temperature Minima in year 2013-2016 :',df.Present_Tmin.min())
print('Average Present Minimum Temperature in year 2013-2016 :',df.Present_Tmin.mean())
# Out:
# Present Maximum Temperature Maxima in year 2013-2016 : 37.6
# Present Maximum Temperature Minima in year 2013-2016 : 20.0
#  Average Present Maximum Temperature in year 2013-2016 : 29.748365840801267
# ====================================================================================================
# Present Minimum Temperature Maxima in year 2013-2016 : 29.9
# Present Minimum Temperature Minima in year 2013-2016 : 11.3
# Average Present Minimum Temperature in year 2013-2016 : 23.195809172377437

# %%
pd.set_option('display.max_columns', None)
df.loc[df.Present_Tmax==df.Present_Tmax.max()]
# Out:
#       station       Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 5717     18.0 2016-08-11          37.6          26.8    44.254253
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  \
# 5717    87.745514         34.794021         27.150764  6.366598  111.225118
#
#       LDAPS_CC1  LDAPS_CC2  LDAPS_CC3  LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT2  \
# 5717   0.218892   0.094288   0.004283   0.000343         0.0         0.0
#
#       LDAPS_PPT3  LDAPS_PPT4      lat      lon      DEM   Slope  \
# 5717         0.0         0.0  37.4832  127.024  56.4448  1.2313
#
#       Solar radiation  Next_Tmax  Next_Tmin  Day  Month  Year
# 5717      5082.563477       37.0       27.8   11      8  2016

# %%
df.loc[df.Present_Tmin==df.Present_Tmin.max()]
# Out:
#       station       Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 2397     23.0 2014-08-02          35.3          29.9    53.946949
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 2397    85.985161         30.912804         25.439537  13.011129  117.837212
#
#       LDAPS_CC1  LDAPS_CC2  LDAPS_CC3  LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT2  \
# 2397   0.684685   0.448827   0.762858   0.635728    1.670126    0.005681
#
#       LDAPS_PPT3  LDAPS_PPT4      lat      lon      DEM   Slope  \
# 2397    0.248885    0.003176  37.5372  126.891  15.5876  0.1554
#
#       Solar radiation  Next_Tmax  Next_Tmin  Day  Month  Year
# 2397      5360.226563       31.3       24.8    2      8  2014

# %%
#to get city and state need further implementations
# Importing Reverse geocoder
# !pip install reverse_geocoder
import reverse_geocoder as rg
import pprint
# Out:
# Collecting reverse_geocoder
#   Downloading reverse_geocoder-1.5.1.tar.gz (2.2 MB)
#      ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#      -------------- ------------------------- 0.8/2.2 MB 17.0 MB/s eta 0:00:01
#      ---------------------------------------  2.2/2.2 MB 28.6 MB/s eta 0:00:01
#      ---------------------------------------- 2.2/2.2 MB 20.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.11.0 in c:\users\dell\anaconda3\lib\site-packages (from reverse_geocoder) (1.24.3)
# Requirement already satisfied: scipy>=0.17.1 in c:\users\dell\anaconda3\lib\site-packages (from reverse_geocoder) (1.11.1)
# Building wheels for collected packages: reverse_geocoder
#   Building wheel for reverse_geocoder (setup.py): started
#   Building wheel for reverse_geocoder (setup.py): finished with status 'done'
#   Created wheel for reverse_geocoder: filename=reverse_geocoder-1.5.1-py3-none-any.whl size=2268077 sha256=6d1dcce6f20d1f55abf13f19ce7588bb07592cc4fa216d232dad57ee59abb32c
#   Stored in directory: c:\users\dell\appdata\local\pip\cache\wheels\17\3c\41\2bc89719586c2a5c53e9a527daa76a968a1288315c1ae2d904
# Successfully built reverse_geocoder
# Installing collected packages: reverse_geocoder
# Successfully installed reverse_geocoder-1.5.1

# %%
geodata=[]
def reverse_geocoordinates(coordinates):
    result = rg.search(coordinates)
    return (result)

if __name__=="__main__":
    coordinates = list(zip(df['lat'], df['lon']))
    data = reverse_geocoordinates(coordinates)
    geodata.append(data)
# Creating dataframe for geographical name
geo_names = pd.DataFrame(geodata).transpose()
# Out:
# Loading formatted geocoded file...

# %%
df['State']= geo_names[0].apply(lambda x:x.get('admin1'))
df['City']=geo_names[0].apply(lambda x:x.get('name'))

# %%
df.head()
# Out:
#     station       Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0       1.0 2013-06-30          28.7          21.4    58.255688    91.116364
# 24     25.0 2013-06-30          32.5          24.2    50.274609    75.525017
# 23     24.0 2013-06-30          31.5          25.0    52.072784    73.693947
# 22     23.0 2013-06-30          32.7          24.4    54.705585    75.919823
# 21     22.0 2013-06-30          32.2          23.9    54.512455    88.524696
#
#     LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS   LDAPS_LH  LDAPS_CC1  \
# 0          28.074101         23.006936  6.818887  69.451805   0.233947
# 24         29.963753         24.972864  6.265457  23.342176   0.283318
# 23         29.344252         24.856806  6.222672  49.007520   0.342294
# 22         28.857981         24.733711  6.019616  90.838489   0.346090
# 21         29.188870         23.801352  6.020390  88.078209   0.179406
#
#     LDAPS_CC2  LDAPS_CC3  LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  \
# 0    0.203896   0.161697   0.130928         0.0         0.0         0.0
# 24   0.289610   0.203459   0.142098         0.0         0.0         0.0
# 23   0.346847   0.213115   0.150829         0.0         0.0         0.0
# 22   0.350199   0.225513   0.148333         0.0         0.0         0.0
# 21   0.268662   0.223249   0.164155         0.0         0.0         0.0
#
#     LDAPS_PPT4      lat      lon       DEM   Slope  Solar radiation  \
# 0          0.0  37.6046  126.991  212.3350  2.7850      5992.895996
# 24         0.0  37.5237  126.970   19.5844  0.2713      5855.093750
# 23         0.0  37.5237  126.909   17.2956  0.2223      5850.358887
# 22         0.0  37.5372  126.891   15.5876  0.1554      5851.387695
# 21         0.0  37.5102  127.086   21.9668  0.1332      5852.904297
#
#     Next_Tmax  Next_Tmin  Day  Month  Year        State        City
# 0        29.1       21.2   30      6  2013        Seoul       Seoul
# 24       32.0       24.2   30      6  2013  Gyeonggi-do   Goyang-si
# 23       31.3       23.7   30      6  2013  Gyeonggi-do     Guri-si
# 22       31.8       23.2   30      6  2013  Gyeonggi-do   Anyang-si
# 21       32.6       23.7   30      6  2013  Gyeonggi-do  Bucheon-si

# %%
Category = ['State', 'City']
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in Category:
    df[i] = le.fit_transform(df[i])
df.head()
# Out:
#     station       Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0       1.0 2013-06-30          28.7          21.4    58.255688    91.116364
# 24     25.0 2013-06-30          32.5          24.2    50.274609    75.525017
# 23     24.0 2013-06-30          31.5          25.0    52.072784    73.693947
# 22     23.0 2013-06-30          32.7          24.4    54.705585    75.919823
# 21     22.0 2013-06-30          32.2          23.9    54.512455    88.524696
#
#     LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS   LDAPS_LH  LDAPS_CC1  \
# 0          28.074101         23.006936  6.818887  69.451805   0.233947
# 24         29.963753         24.972864  6.265457  23.342176   0.283318
# 23         29.344252         24.856806  6.222672  49.007520   0.342294
# 22         28.857981         24.733711  6.019616  90.838489   0.346090
# 21         29.188870         23.801352  6.020390  88.078209   0.179406
#
#     LDAPS_CC2  LDAPS_CC3  LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  \
# 0    0.203896   0.161697   0.130928         0.0         0.0         0.0
# 24   0.289610   0.203459   0.142098         0.0         0.0         0.0
# 23   0.346847   0.213115   0.150829         0.0         0.0         0.0
# 22   0.350199   0.225513   0.148333         0.0         0.0         0.0
# 21   0.268662   0.223249   0.164155         0.0         0.0         0.0
#
#     LDAPS_PPT4      lat      lon       DEM   Slope  Solar radiation  \
# 0          0.0  37.6046  126.991  212.3350  2.7850      5992.895996
# 24         0.0  37.5237  126.970   19.5844  0.2713      5855.093750
# 23         0.0  37.5237  126.909   17.2956  0.2223      5850.358887
# 22         0.0  37.5372  126.891   15.5876  0.1554      5851.387695
# 21         0.0  37.5102  127.086   21.9668  0.1332      5852.904297
#
#     Next_Tmax  Next_Tmin  Day  Month  Year  State  City
# 0        29.1       21.2   30      6  2013      1     6
# 24       32.0       24.2   30      6  2013      0     2
# 23       31.3       23.7   30      6  2013      0     3
# 22       31.8       23.2   30      6  2013      0     0
# 21       32.6       23.7   30      6  2013      0     1

# %%
# drop unwanted column
# Droping unnecessary columns
df.drop(['Date'], axis=1, inplace=True)

# %% [markdown]
# 1. Outliers Detection and Removal

# %%
plt.figure(figsize=(20,45),facecolor='white')
plotnumber=1

for column in df:
    if plotnumber<=29:
        ax=plt.subplot(10,3,plotnumber)
        sns.boxplot(df[column],color='g')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# Outliers removal using Zscore method

# %%
from scipy.stats import zscore
z = np.abs(zscore(df))
threshold = 3
df1 = df[(z<3).all(axis = 1)]

print ("Shape of the dataframe before removing outliers: ", df.shape)
print ("Shape of the dataframe after removing outliers: ", df1.shape)
print ("Percentage of data loss post outlier removal: ", (df.shape[0]-df1.shape[0])/df.shape[0]*100)

df=df1.copy() # reassigning the changed dataframe name to our original dataframe name
# Out:
# Shape of the dataframe before removing outliers:  (7588, 29)
# Shape of the dataframe after removing outliers:  (6739, 29)
# Percentage of data loss post outlier removal:  11.188719030047443

# %% [markdown]
# 2. Skewness of features

# %%
plt.figure(figsize=(20,40),facecolor='white')
sns.set_palette('rainbow')
plotnum=1
for col in df:
    if plotnum<=29:
        plt.subplot(10,3,plotnum)
        sns.distplot(df[col])
        plt.xlabel(col,fontsize=20)
    plotnum+=1
plt.show()

# %%
df.skew()
# Out:
# station            -0.001594
# Present_Tmax       -0.269936
# Present_Tmin       -0.221250
# LDAPS_RHmin         0.309567
# LDAPS_RHmax        -0.686083
# LDAPS_Tmax_lapse   -0.110563
# LDAPS_Tmin_lapse   -0.379269
# LDAPS_WS            1.085685
# LDAPS_LH            0.567050
# LDAPS_CC1           0.594835
# LDAPS_CC2           0.505774
# LDAPS_CC3           0.701288
# LDAPS_CC4           0.708754
# LDAPS_PPT1          3.724580
# LDAPS_PPT2          4.854967
# LDAPS_PPT3          5.516862
# LDAPS_PPT4          5.924324
# lat                 0.106983
# lon                -0.277547
# DEM                 1.764698
# Slope               1.590130
# Solar radiation    -0.520157
# Next_Tmax          -0.267526
# Next_Tmin          -0.234328
# Day                 0.000057
# Month              -0.168571
# Year                0.025066
# State               0.133391
# City               -0.969408
# dtype: float64

# %% [markdown]
# 3. Corrleation

# %%
df.corr()
# Out:
#                    station  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# station           1.000000      0.110291      0.133638    -0.069582
# Present_Tmax      0.110291      1.000000      0.610428    -0.154266
# Present_Tmin      0.133638      0.610428      1.000000     0.151385
# LDAPS_RHmin      -0.069582     -0.154266      0.151385     1.000000
# LDAPS_RHmax      -0.176388     -0.297804     -0.039688     0.552581
# LDAPS_Tmax_lapse  0.066863      0.540680      0.441577    -0.555583
# LDAPS_Tmin_lapse  0.104401      0.616886      0.764258     0.129481
# LDAPS_WS          0.023075     -0.105162      0.018711     0.236324
# LDAPS_LH         -0.135023      0.130771     -0.004055    -0.035217
# LDAPS_CC1         0.008671     -0.290078      0.090828     0.574389
# LDAPS_CC2         0.006380     -0.157917      0.117894     0.713238
# LDAPS_CC3         0.006875     -0.060549      0.041457     0.653782
# LDAPS_CC4         0.011167     -0.049339     -0.006979     0.458417
# LDAPS_PPT1       -0.001758     -0.135546      0.073741     0.289740
# LDAPS_PPT2       -0.021036     -0.040151      0.084705     0.376428
# LDAPS_PPT3        0.002851     -0.015137      0.036206     0.257765
# LDAPS_PPT4        0.015223     -0.042837     -0.055364     0.185176
# lat              -0.241811     -0.052041     -0.072707     0.090054
# lon              -0.122829      0.011132     -0.043201    -0.093969
# DEM              -0.257894     -0.168792     -0.241396     0.094391
# Slope            -0.096863     -0.091336     -0.138107     0.119216
# Solar radiation  -0.032810     -0.059891      0.020030     0.251733
# Next_Tmax         0.106378      0.586943      0.438813    -0.433872
# Next_Tmin         0.129110      0.615950      0.785946     0.134518
# Day               0.005032     -0.130708     -0.082712    -0.073118
# Month             0.011380      0.169326      0.106547    -0.179437
# Year              0.006658      0.099185      0.099222     0.001709
# State             0.019212     -0.043555     -0.057586    -0.070502
# City              0.072419     -0.022100     -0.039699    -0.039795
#
#                   LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  \
# station             -0.176388          0.066863          0.104401  0.023075
# LDAPS_CC3          0.000194 -0.049020 -0.101688  0.105248 -0.012992 -0.010083
# LDAPS_CC4         -0.041994 -0.021545 -0.096240  0.111331 -0.009688 -0.011972
# LDAPS_PPT1        -0.029752 -0.001267 -0.148748 -0.062439 -0.006678 -0.006644
# LDAPS_PPT2         0.004340  0.018520 -0.082983 -0.048360 -0.023890 -0.016016
# LDAPS_PPT3         0.023274  0.002885  0.033237  0.022291 -0.008980 -0.006976
# LDAPS_PPT4        -0.106821 -0.024902  0.005427  0.060048  0.043557  0.020183
# lat               -0.076705 -0.003366 -0.009057  0.001499 -0.000596  0.042712
# lon               -0.041574 -0.002923 -0.009403 -0.005863 -0.003983  0.027762
# DEM               -0.237683 -0.006199  0.000137  0.003206  0.008105  0.019088
# Slope             -0.136838 -0.005705 -0.002226  0.002771 -0.011969  0.015582
# Solar radiation    0.083207 -0.392844 -0.839270  0.031072 -0.072562 -0.033105
# Next_Tmax          0.580951 -0.108606  0.118184  0.101615 -0.042543 -0.017730
# Next_Tmin          1.000000 -0.102557  0.056805  0.069291 -0.071963 -0.044472
# Day               -0.102557  1.000000 -0.120944 -0.039453  0.047139  0.019411
# Month              0.056805 -0.120944  1.000000 -0.008937  0.043688  0.023237
# Year               0.069291 -0.039453 -0.008937  1.000000  0.066859  0.035501
# State             -0.071963  0.047139  0.043688  0.066859  1.000000  0.842139
# City              -0.044472  0.019411  0.023237  0.035501  0.842139  1.000000

# %%
plt.figure(figsize=(25,15))
sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, square=True, fmt='0.3f', 
            annot_kws={'size':10}, cmap="gist_stern")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
plt.figure(figsize = (18,6))
df.corr()['Next_Tmax'].drop(['Next_Tmax']).sort_values(ascending=False).plot(kind='bar',color = 'purple')
plt.xlabel('Features',fontsize=15,fontweight='bold')
plt.ylabel('Next_Tmax',fontsize=15,fontweight='bold')
plt.title('Correlation of features with Target Variable Next_Tmax',fontsize = 20,fontweight='bold')
plt.show()

# %%
plt.figure(figsize = (18,6))
df.corr()['Next_Tmin'].drop(['Next_Tmin']).sort_values(ascending=False).plot(kind='bar',color = 'purple')
plt.xlabel('Features',fontsize=15,fontweight='bold')
plt.ylabel('Next_Tmin',fontsize=15,fontweight='bold')
plt.title('Correlation of features with Target Variable Next_Tmin',fontsize = 20,fontweight='bold')
plt.show()

# %%
# Splitting data in target and dependent feature
X = df.drop(['Next_Tmax'], axis =1)
Y = df['Next_Tmax']

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(X_scale,i) for i in range(len(X.columns))]
vif["Features"] = X.columns
vif
# Out:
#     VIF values          Features
# 0     1.262806           station
# 1     2.820724      Present_Tmax
# 2     3.454114      Present_Tmin
# 3     6.186160       LDAPS_RHmin
# 4     2.302590       LDAPS_RHmax
# 5     7.378038  LDAPS_Tmax_lapse
# 6     9.019676  LDAPS_Tmin_lapse
# 7     1.264588          LDAPS_WS
# 8     1.562885          LDAPS_LH
# 9     3.551737         LDAPS_CC1
# 10    4.718567         LDAPS_CC2
# 11    4.996554         LDAPS_CC3
# 12    2.736749         LDAPS_CC4
# 13    1.568510        LDAPS_PPT1
# 14    1.423012        LDAPS_PPT2
# 15    1.267060        LDAPS_PPT3
# 16    1.306056        LDAPS_PPT4
# 17    1.313335               lat
# 18    1.179722               lon
# 19    3.934729               DEM
# 20    3.181857             Slope
# 21   39.140247   Solar radiation
# 22    5.750344         Next_Tmin
# 23   10.137640               Day
# 24   32.303806             Month
# 25    1.159312              Year
# 26    3.625948             State
# 27    3.593831              City

# %%
from sklearn.decomposition import PCA
pca = PCA()
#plot the graph to find the principal components
x_pca = pca.fit_transform(X_scale)
plt.figure(figsize=(10,10))
plt.plot(np.cumsum(pca.explained_variance_ratio_), 'ro-')
plt.xlabel('Number of Components')
plt.ylabel('Variance %')
plt.title('Explained variance Ratio')
plt.grid()

# %%
pca_new = PCA(n_components=15)
x_new = pca_new.fit_transform(X_scale)

# %%
principle_x=pd.DataFrame(x_new,columns=np.arange(15))

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Obtaining dependency information for xgboost from https://files.pythonhosted.org/packages/a2/48/d5da8591891327b0faf08179d420fba3893c6134bdd449497c5329e4cb01/xgboost-2.1.0-py3-none-win_amd64.whl.metadata
#   Downloading xgboost-2.1.0-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in c:\users\dell\anaconda3\lib\site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in c:\users\dell\anaconda3\lib\site-packages (from xgboost) (1.11.1)
# Downloading xgboost-2.1.0-py3-none-win_amd64.whl (124.9 MB)
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/124.9 MB 1.7 MB/s eta 0:01:12
#    ---------------------------------------- 0.2/124.9 MB 3.0 MB/s eta 0:00:42
#    ---------------------------------------- 0.4/124.9 MB 2.2 MB/s eta 0:00:56
#    ---------------------------------------- 0.4/124.9 MB 2.2 MB/s eta 0:00:56
#    ---------------------------------------- 0.5/124.9 MB 2.2 MB/s eta 0:00:56
#    ---------------------------------------- 0.7/124.9 MB 2.6 MB/s eta 0:00:48
#    ---------------------------------------- 0.7/124.9 MB 2.6 MB/s eta 0:00:48
#    ---------------------------------------- 0.9/124.9 MB 2.5 MB/s eta 0:00:51
#    ---------------------------------------- 1.1/124.9 MB 2.7 MB/s eta 0:00:46
#    ---------------------------------------- 1.1/124.9 MB 2.7 MB/s eta 0:00:46
#    ---------------------------------------- 1.3/124.9 MB 2.5 MB/s eta 0:00:50
#    ---------------------------------------- 1.4/124.9 MB 2.4 MB/s eta 0:00:51
#    ---------------------------------------- 1.5/124.9 MB 2.3 MB/s eta 0:00:53
#    ---------------------------------------- 1.5/124.9 MB 2.4 MB/s eta 0:00:53
#     --------------------------------------- 1.6/124.9 MB 2.3 MB/s eta 0:00:55
#    ------------- -------------------------- 43.1/124.9 MB 7.0 MB/s eta 0:00:12
#    ------------- -------------------------- 43.5/124.9 MB 7.0 MB/s eta 0:00:12
#    -------------- ------------------------- 43.8/124.9 MB 7.1 MB/s eta 0:00:12
#    -------------- ------------------------- 44.2/124.9 MB 7.2 MB/s eta 0:00:12
#    -------------- ------------------------- 44.6/124.9 MB 7.3 MB/s eta 0:00:12
#    -------------- ------------------------- 45.0/124.9 MB 7.4 MB/s eta 0:00:11
#    -------------- ------------------------- 45.5/124.9 MB 7.4 MB/s eta 0:00:11
#    -------------- ------------------------- 45.9/124.9 MB 7.4 MB/s eta 0:00:11
#    -------------- ------------------------- 46.3/124.9 MB 7.4 MB/s eta 0:00:11
#    -------------- ------------------------- 46.7/124.9 MB 7.5 MB/s eta 0:00:11
#    --------------- ------------------------ 47.1/124.9 MB 7.5 MB/s eta 0:00:11
#    --------------- ------------------------ 47.5/124.9 MB 7.5 MB/s eta 0:00:11
#    --------------- ------------------------ 47.8/124.9 MB 7.6 MB/s eta 0:00:11
#    --------------- ------------------------ 48.3/124.9 MB 7.6 MB/s eta 0:00:11
#    --------------- ------------------------ 48.6/124.9 MB 7.7 MB/s eta 0:00:10
#    --------------- ------------------------ 49.0/124.9 MB 7.6 MB/s eta 0:00:10
#    --------------- ------------------------ 49.4/124.9 MB 7.7 MB/s eta 0:00:10
#    --------------- ------------------------ 49.8/124.9 MB 7.8 MB/s eta 0:00:10
#    ---------------- ----------------------- 50.1/124.9 MB 7.9 MB/s eta 0:00:10
#    ---------------- ----------------------- 50.5/124.9 MB 7.9 MB/s eta 0:00:10
#    ---------------- ----------------------- 51.0/124.9 MB 7.9 MB/s eta 0:00:10
#    ---------------- ----------------------- 51.3/124.9 MB 7.9 MB/s eta 0:00:10
#    ---------------- ----------------------- 51.7/124.9 MB 7.9 MB/s eta 0:00:10
#    ---------------- ----------------------- 52.0/124.9 MB 7.9 MB/s eta 0:00:10
#    ---------------- ----------------------- 52.5/124.9 MB 7.9 MB/s eta 0:00:10
#    ---------------- ----------------------- 52.9/124.9 MB 8.0 MB/s eta 0:00:10
#    ----------------- ---------------------- 53.2/124.9 MB 8.0 MB/s eta 0:00:09
#    ----------------- ---------------------- 53.5/124.9 MB 7.9 MB/s eta 0:00:10
#    ----------------- ---------------------- 53.9/124.9 MB 7.9 MB/s eta 0:00:09
#    ----------------- ---------------------- 54.2/124.9 MB 8.0 MB/s eta 0:00:09
#    ----------------- ---------------------- 54.7/124.9 MB 7.9 MB/s eta 0:00:09
#    ----------------- ---------------------- 55.1/124.9 MB 7.9 MB/s eta 0:00:09
#    ----------------- ---------------------- 55.4/124.9 MB 7.9 MB/s eta 0:00:09
#    ----------------- ---------------------- 55.8/124.9 MB 8.0 MB/s eta 0:00:09
#    ------------------ --------------------- 56.3/124.9 MB 8.0 MB/s eta 0:00:09
#    ------------------ --------------------- 56.8/124.9 MB 8.2 MB/s eta 0:00:09
#    ------------------ --------------------- 57.1/124.9 MB 8.2 MB/s eta 0:00:09
#    ------------------ --------------------- 57.5/124.9 MB 8.1 MB/s eta 0:00:09
#    ------------------ --------------------- 57.9/124.9 MB 8.1 MB/s eta 0:00:09
#    ------------------ --------------------- 58.4/124.9 MB 8.2 MB/s eta 0:00:09
MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 21.8 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 21.8 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 21.8 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 21.8 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 21.8 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 21.8 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 21.8 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 21.8 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 21.8 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 21.8 MB/s eta 0:00:01
#    --------------------------------------  124.9/124.9 MB 21.8 MB/s eta 0:00:01
#    ---------------------------------------- 124.9/124.9 MB 5.0 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-2.1.0

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
import xgboost as xgb
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import  GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import  Ridge
from sklearn.linear_model import  Lasso
from xgboost import XGBRegressor

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=42, test_size=.33)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (4515, 15)
# Training target vector size: (4515,)
# Test feature matrix size: (2224, 15)
# Test target vector size: (2224,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
maxR2_score=0
maxRS=0
for i in range(1,500):
    X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=i, test_size=.33)
    lin_reg=LinearRegression()
    lin_reg.fit(X_train,Y_train)
    y_pred=lin_reg.predict(X_test)
    R2=r2_score(Y_test,y_pred)
    if R2>maxR2_score:
        maxR2_score=R2
        maxRS=i
print('Best R2 Score is', maxR2_score ,'on Random_state', maxRS)
# Out:
# Best R2 Score is 0.8052663714497941 on Random_state 499

# %%
#Linear Regression Base Model
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=108, test_size=.33)
lin_reg=LinearRegression()
lin_reg.fit(X_train,Y_train)
lin_reg.score(X_train,Y_train)
y_pred=lin_reg.predict(X_test)
print('\033[1m'+'Predicted Wins:'+'\033[0m\n',y_pred)
print('\n')
print('\033[1m'+'Actual Wins:'+'\033[0m\n',Y_test)
# Out:
# Predicted Wins:
#  [31.54532414 30.61164988 29.99903916 ... 25.96777192 26.12128393
#  31.72832326]
#
#
# Actual Wins:
#  944     32.3
# 4597    31.0
# 7292    28.5
# 4790    26.7
# 3771    29.9
#         ...
# 7082    36.8
# 7134    32.0
# 7654    25.9
# 5074    23.7
# 4236    30.9
# Name: Next_Tmax, Length: 2224, dtype: float64

# %%
print('\033[1m'+' Error :'+'\033[0m')
print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
print('Mean squared error :', mean_squared_error(Y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
print('\n')
from sklearn.metrics import r2_score
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(Y_test,y_pred,multioutput='variance_weighted'))
# Out:
#  Error :
# Mean absolute error : 1.0240215145023541
# Mean squared error : 1.7705844689582941
# Root Mean Squared Error: 1.3306331083203566
#
#
#  R2 Score :
# 0.8000947167249379

# %%
# Cross Validation
from sklearn.model_selection import cross_val_score
score = cross_val_score(lin_reg, X_scale, Y, cv =3)
print('\033[1m'+'Cross Validation Score :',lin_reg,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
# Out:
# Cross Validation Score : LinearRegression() :
#
# Mean CV Score : 0.6624007518265644

# %%
#Applying other ML Models
from sklearn.ensemble import BaggingRegressor
rf = RandomForestRegressor()
dtc = DecisionTreeRegressor()
XT = ExtraTreesRegressor()
BR = BaggingRegressor()
adb=AdaBoostRegressor()
gradb=GradientBoostingRegressor()
xgb=XGBRegressor()
model = [rf,XT,dtc,adb,gradb,xgb]

for m in model:
    m.fit(X_train,Y_train)
    m.score(X_train,Y_train)
    y_pred = m.predict(X_test)
    print('\n')                                        
    print('\033[1m'+' Error of ', m, ':' +'\033[0m')
    print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
    print('Mean squared error :', mean_squared_error(Y_test,y_pred))
    print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
    print('\n')

    print('\033[1m'+' R2 Score :'+'\033[0m')
    print(r2_score(Y_test,y_pred)) 
    print('===========================')
# Out:
#  Error of  RandomForestRegressor() :
# Mean absolute error : 0.7008673561151079
# Mean squared error : 0.8855486461330935
# Root Mean Squared Error: 0.9410359430612061
#
#
#  R2 Score :
# 0.9000184085748616
# ===========================
#
#
#  Error of  ExtraTreesRegressor() :
# Mean absolute error : 0.6068480215827337
# Mean squared error : 0.6579046600719418
# Root Mean Squared Error: 0.8111132227204423
#
#
#  R2 Score :
# 0.9257202241714891
# ===========================
#
#
#  Error of  DecisionTreeRegressor() :
# Mean absolute error : 1.0354766187050357
# Mean squared error : 2.017081834532374
# Root Mean Squared Error: 1.4202400622896025
#
#
#  R2 Score :
# 0.7722642875330259
# ===========================
#
#
#  Error of  AdaBoostRegressor() :
# Mean absolute error : 1.1308338996249843
# Mean squared error : 1.9699872874044508
# Root Mean Squared Error: 1.4035623560798611
#
#
#  R2 Score :
# 0.7775814293861096
# ===========================
#
#
#  Error of  GradientBoostingRegressor() :
# Mean absolute error : 0.8499401236751107
# Mean squared error : 1.2068715175200022
# Root Mean Squared Error: 1.098577042141334
#
#
#  R2 Score :
# 0.8637399136747297
# ===========================
#
#
#  Error of  XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...) :
# Mean absolute error : 0.6233783845421221
# Mean squared error : 0.6968576416060417
# Root Mean Squared Error: 0.8347799959306893
#
#
#  R2 Score :
# 0.9213222940277983
# ===========================

# %%
# Cross Validation
model = [rf,XT,dtc,adb,gradb,xgb]

for m in model:
    score = cross_val_score(m, X_scale, Y, cv =5)
    print('\n')
    print('\033[1m'+'Cross Validation Score :',m,":"+'\033[0m\n')
    print("Mean CV Score :",score.mean())
    print('==================================================')
# Out:
# Cross Validation Score : RandomForestRegressor() :
#
# Mean CV Score : 0.6867188242705019
# ==================================================
#
#
# Cross Validation Score : ExtraTreesRegressor() :
#
# Mean CV Score : 0.6926854313862618
# ==================================================
#
#
# Cross Validation Score : DecisionTreeRegressor() :
#
# Mean CV Score : 0.40035725317555215
# ==================================================
#
#
# Cross Validation Score : AdaBoostRegressor() :
#
# Mean CV Score : 0.6485099991030493
# ==================================================
#
#
# Cross Validation Score : GradientBoostingRegressor() :
#
# Mean CV Score : 0.7091496504073292
# ==================================================
#
#
# Cross Validation Score : XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...) :
#
# Mean CV Score : 0.662482224466211
# ==================================================

# %% [markdown]
# # Hyper Parameter Tuning : GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV
parameter = {'n_estimators':[200,400,500,600],'gamma':np.arange(0,0.2,0.1),
              'booster' : ['gbtree','dart','gblinear'], 'max_depth':[4,6,8,10],
              'eta' : [0.001, 0.01, 0.1] }
GCV = GridSearchCV(XGBRegressor(),parameter,verbose =10)
GCV.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# [CV 1/5; 1/288] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=200
# [CV 1/5; 1/288] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=200;, score=0.214 total time=   0.4s
# [CV 2/5; 1/288] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=200
# [CV 2/5; 1/288] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=200;, score=0.227 total time=   0.4s
# [CV 3/5; 1/288] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=200
# [CV 3/5; 1/288] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=200;, score=0.216 total time=   0.4s
# [CV 4/5; 1/288] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=200
# [CV 4/5; 1/288] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=200;, score=0.235 total time=   0.4s
# [CV 5/5; 1/288] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=200
# [CV 5/5; 1/288] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=200;, score=0.235 total time=   0.3s
# [CV 1/5; 2/288] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=400
# [CV 1/5; 2/288] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=400;, score=0.374 total time=   0.8s
# [CV 2/5; 2/288] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=400
# [CV 2/5; 2/288] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=400;, score=0.387 total time=   0.9s
# [CV 3/5; 2/288] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=400
# [CV 3/5; 2/288] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=400;, score=0.374 total time=   0.8s
# [CV 4/5; 2/288] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=400
# [CV 4/5; 2/288] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=400;, score=0.399 total time=   0.8s
# [CV 5/5; 2/288] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=400
# [CV 5/5; 2/288] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=400;, score=0.399 total time=   0.8s
# [CV 1/5; 3/288] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=500
# [CV 1/5; 3/288] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=500;, score=0.436 total time=   1.0s
# [CV 2/5; 3/288] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=500
# [CV 2/5; 3/288] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=500;, score=0.448 total time=   1.2s
# [CV 3/5; 3/288] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=500
# [CV 3/5; 3/288] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=500;, score=0.434 total time=   1.1s
# [CV 4/5; 3/288] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=500
# [CV 4/5; 3/288] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=500;, score=0.462 total time=   1.2s
# [CV 5/5; 3/288] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=500
# [CV 5/5; 3/288] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=500;, score=0.462 total time=   1.0s
# [CV 1/5; 4/288] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=600
# [CV 1/5; 4/288] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=600;, score=0.488 total time=   1.2s
# [CV 2/5; 4/288] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=600
# [CV 2/5; 4/288] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=600;, score=0.498 total time=   1.3s
# [CV 3/5; 4/288] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=600
# [CV 3/5; 4/288] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=600;, score=0.485 total time=   1.3s
# [CV 4/5; 4/288] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=600
# [CV 4/5; 4/288] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=600;, score=0.513 total time=   1.3s
# [CV 5/5; 4/288] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=600
# [CV 5/5; 4/288] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=600;, score=0.514 total time=   1.5s
# [CV 1/5; 5/288] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=200
# [CV 1/5; 5/288] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=200;, score=0.236 total time=   1.1s
# [CV 2/5; 5/288] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators
288] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=400;, score=0.435 total time=  13.1s
# [CV 4/5; 30/288] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=400
# [CV 4/5; 30/288] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=400;, score=0.440 total time=  11.2s
# [CV 5/5; 30/288] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=400
# [CV 5/5; 30/288] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=400;, score=0.446 total time=  11.3s
# [CV 1/5; 31/288] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=500
# [CV 1/5; 31/288] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=500;, score=0.497 total time=  12.2s
# [CV 2/5; 31/288] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=500
# [CV 2/5; 31/288] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=500;, score=0.518 total time=  14.6s
# [CV 3/5; 31/288] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=500
# [CV 3/5; 31/288] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=500;, score=0.504 total time=  14.6s
# [CV 4/5; 31/288] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=500
# [CV 4/5; 31/288] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=500;, score=0.507 total time=  14.9s
# [CV 5/5; 31/288] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=500
# [CV 5/5; 31/288] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=500;, score=0.515 total time=  14.9s
# [CV 1/5; 32/288] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=600
# [CV 1/5; 32/288] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=600;, score=0.556 total time=  17.7s
# [CV 2/5; 32/288] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=600
# [CV 2/5; 32/288] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=600;, score=0.577 total time=  17.5s
# [CV 3/5; 32/288] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=600
# [CV 3/5; 32/288] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=600;, score=0.561 total time=  18.3s
# [CV 4/5; 32/288] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=600
# [CV 4/5; 32/288] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=600;, score=0.564 total time=  17.8s
# [CV 5/5; 32/288] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=600
# [CV 5/5; 32/288] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=600;, score=0.572 total time=  17.9s
# [CV 1/5; 33/288] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=200
# [CV 1/5; 33/288] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=200;, score=0.772 total time=   0.3s
# [CV 2/5; 33/288] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=200
# [CV 2/5; 33/288] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=200;, score=0.760 total time=   0.3s
# [CV 3/5; 33/288] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=200
# [CV 3/5; 33/288] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=200;, score=0.751 total time=   0.3s
# [CV 4/5; 33/288] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=200
# [CV 4/5; 33/288] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=200;, score=0.773 total time=   0.3s
# [CV 5/5; 33/288] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=200
# [CV 5/5; 33/288] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=200;, score=0.791 total time=   0.3s
# [CV 1/5; 34/288] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=400
# [CV 1/5; 34/288] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=400;, score=0.844 total time=   0.7s
# [CV 2/5; 34/288] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=400
# [CV 2/5; 34/288] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=400;, score=0.827 total time=   0.7s
# [CV 3/5; 34/288] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=400
# [CV 3/5; 34/288] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=400;, score=0.820 total time=   0.8s
# [CV 4/5; 34/288] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=400
# [CV 4/5; 34/288] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=400;, score=0.833 total time=   0.7s
# [CV 5/5; 34/288] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=400
# [CV 5/5; 34/288] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=400;, score=0.857 total time=   0.7s
# [CV 1/5; 35/288] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=500
# [CV 1/5; 35/288] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=500;, score=0.854 total time=   0.9s
# [CV 2/5; 35/288] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=500
# [CV 2/5; 35/288] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=500;, score=0.837 total time=   0.9s
# [CV 3/5; 35/288] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=500
# [CV 3/5; 35/288] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=500;, score=0.831 total time=   0.9s
# [CV 4/5; 35/288] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=500
# [CV 4/5; 35/288] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=500;, score=0.845 total time=   0.9s
# [CV 5/5; 35/288] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=500
# [CV 5/5; 35/288] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=500;, score=0.867 total time=   0.9s
# [CV 1/5; 36/288] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=600
# [CV 1/5; 36/288] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=600;, score=0.861 total time=   1.1s
# [CV 2/5; 36/288] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=600
# [CV 2/5; 36/288] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=600;, score=0.843 total time=   1.1s
# [CV 3/5; 36/288] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=600
# [CV 3/5; 36/288] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=600;, score=0.839 total time=   1.1s
# [CV 4/5; 36/288] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=600
# [CV 4/5; 36/288] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators
288] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=600
# [CV 1/5; 44/288] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=600;, score=0.907 total time=   8.8s
# [CV 2/5; 44/288] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=600
# [CV 2/5; 44/288] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=600;, score=0.893 total time=   8.6s
# [CV 3/5; 44/288] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=600
# [CV 3/5; 44/288] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=600;, score=0.887 total time=   8.7s
# [CV 4/5; 44/288] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=600
# [CV 4/5; 44/288] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=600;, score=0.896 total time=  10.6s
# [CV 5/5; 44/288] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=600
# [CV 5/5; 44/288] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=600;, score=0.907 total time=  10.1s
# [CV 1/5; 45/288] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=200
# [CV 1/5; 45/288] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=200;, score=0.849 total time=   6.6s
# [CV 2/5; 45/288] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=200
# [CV 2/5; 45/288] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=200;, score=0.854 total time=   6.6s
# [CV 3/5; 45/288] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=200
# [CV 3/5; 45/288] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=200;, score=0.837 total time=   6.6s
# [CV 4/5; 45/288] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=200
# [CV 4/5; 45/288] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=200;, score=0.838 total time=   6.6s
# [CV 5/5; 45/288] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=200
# [CV 5/5; 45/288] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=200;, score=0.853 total time=   7.7s
# [CV 1/5; 46/288] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=400
# ...
# [CV 3/5; 96/288] START booster=gbtree, eta=0.1, gamma=0.1, max_depth=10, n_estimators=600
# [CV 3/5; 96/288] END booster=gbtree, eta=0.1, gamma=0.1, max_depth=10, n_estimators=600;, score=0.882 total time=   1.8s
# [CV 4/5; 96/288] START booster=gbtree, eta=0.1, gamma=0.1, max_depth=10, n_estimators=600
# [CV 4/5; 96/288] END booster=gbtree, eta=0.1, gamma=0.1, max_depth=10, n_estimators=600;, score=0.884 total time=   1.9s
# [CV 5/5; 96/288] START booster=gbtree, eta=0.1, gamma=0.1, max_depth=10, n_estimators=600
# [CV 5/5; 96/288] END booster=gbtree, eta=0.1, gamma=0.1, max_depth=10, n_estimators=600;, score=0.901 total time=   1.8s
# [CV 1/5; 97/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=200
# [CV 1/5; 97/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=200;, score=0.214 total time=  24.1s
# [CV 2/5; 97/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=200
# [CV 2/5; 97/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=200;, score=0.227 total time=  24.3s
# [CV 3/5; 97/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=200
# [CV 3/5; 97/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=200;, score=0.216 total time=  23.0s
# [CV 4/5; 97/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=200
# [CV 4/5; 97/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=200;, score=0.235 total time=  23.6s
# [CV 5/5; 97/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=200
# [CV 5/5; 97/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=200;, score=0.235 total time=  23.1s
# [CV 1/5; 98/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=400
# [CV 1/5; 98/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=400;, score=0.374 total time= 1.5min
# [CV 2/5; 98/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=400
# [CV 2/5; 98/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=400;, score=0.387 total time= 1.7min
# [CV 3/5; 98/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=400
# [CV 3/5; 98/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=400;, score=0.374 total time= 1.5min
# [CV 4/5; 98/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=400
# [CV 4/5; 98/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=400;, score=0.399 total time= 1.5min
# [CV 5/5; 98/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=400
# [CV 5/5; 98/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=400;, score=0.399 total time= 1.6min
# [CV 1/5; 99/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=500
# [CV 1/5; 99/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=500;, score=0.436 total time= 2.4min
# [CV 2/5; 99/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=500
# [CV 2/5; 99/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=500;, score=0.448 total time= 2.6min
# [CV 3/5; 99/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=500
# [CV 3/5; 99/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=500;, score=0.434 total time= 2.7min
# [CV 4/5; 99/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=500
# [CV 4/5; 99/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=500;, score=0.462 total time= 2.8min
# [CV 5/5; 99/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=500
# [CV 5/5; 99/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=500;, score=0.462 total time=363.2min
# [CV 1/5; 100/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=600
# [CV 1/5; 100/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=600;, score=0.488 total time= 3.4min
# [CV 2/5; 100/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=600
# [CV 2/5; 100/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=600;, score=0.498 total time= 3.3min
# [CV 3/5; 100/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=600
# [CV 3/5; 100/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=600;, score=0.485 total time= 3.3min
# [CV 4/5; 100/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=600
# [CV 4/5; 100/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=600;, score=0.513 total time=767.2min
# [CV 5/5; 100/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=600
# [CV 5/5; 100/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=4, n_estimators=600;, score=0.514 total time= 5.6min
# [CV 1/5; 101/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=200
# [CV 1/5; 101/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=200;, score=0.236 total time=  28.0s
# [CV 2/5; 101/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=200
# [CV 2/5; 101/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=200;, score=0.247 total time=  26.8s
# [CV 3/5; 101/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=200
# [CV 3/5; 101/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=200;, score=0.233 total time=  28.3s
# [CV 4/5; 101/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=200
# [CV 4/5; 101/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=200;, score=0.253 total time=  27.1s
# [CV 5/5; 101/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=200
# [CV 5/5; 101/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=200;, score=0.250 total time=  26.8s
# [CV 1/5; 102/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=400
# [CV 1/5; 102/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=400;, score=0.410 total time= 1.7min
# [CV 2/5; 102/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=400
# [CV 2/5; 102/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=400;, score=0.420 total time= 1.7min
# [CV 3/5; 102/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=400
# [CV 3/5; 102/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=400;, score=0.405 total time= 2.0min
# [CV 4/5; 102/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=400
# [CV 4/5; 102/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=400;, score=0.427 total time= 1.8min
# [CV 5/5; 102/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=400
# [CV 5/5; 102/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=400;, score=0.425 total time= 2.5min
# [CV 1/5; 103/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=500
# [CV 1/5; 103/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=500;, score=0.477 total time= 2.9min
# [CV 2/5; 103/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=500
# [CV 2/5; 103/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=500;, score=0.485 total time= 2.9min
# [CV 3/5; 103/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=500
# [CV 3/5; 103/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=500;, score=0.470 total time= 2.7min
# [CV 4/5; 103/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=500
# [CV 4/5; 103/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=500;, score=0.493 total time= 2.8min
# [CV 5/5; 103/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=500
# [CV 5/5; 103/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=500;, score=0.492 total time= 2.7min
# [CV 1/5; 104/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=600
# [CV 1/5; 104/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=600;, score=0.533 total time= 4.1min
# [CV 2/5; 104/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=600
# [CV 2/5; 104/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=600;, score=0.539 total time=139.6min
# [CV 3/5; 104/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=600
# [CV 3/5; 104/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=600;, score=0.525 total time= 4.4min
# [CV 4/5; 104/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=600
# [CV 4/5; 104/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=600;, score=0.549 total time= 4.0min
# [CV 5/5; 104/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=600
# [CV 5/5; 104/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=6, n_estimators=600;, score=0.547 total time= 3.5min
# [CV 1/5; 105/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=200
# [CV 1/5; 105/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=200;, score=0.245 total time=  27.5s
# [CV 2/5; 105/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=200
# [CV 2/5; 105/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=200;, score=0.261 total time=  26.8s
# [CV 3/5; 105/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=200
# [CV 3/5; 105/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=200;, score=0.247 total time=  27.6s
# [CV 4/5; 105/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=200
# [CV 4/5; 105/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=200;, score=0.258 total time=  28.8s
# [CV 5/5; 105/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=200
# [CV 5/5; 105/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=200;, score=0.260 total time=  34.6s
# [CV 1/5; 106/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=400
# [CV 1/5; 106/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=400;, score=0.427 total time= 1.8min
# [CV 2/5; 106/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=400
# [CV 2/5; 106/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=400;, score=0.442 total time= 1.7min
# [CV 3/5; 106/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=400
# [CV 3/5; 106/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=400;, score=0.427 total time= 1.6min
# [CV 4/5; 106/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=400
# [CV 4/5; 106/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=400;, score=0.439 total time= 1.7min
# [CV 5/5; 106/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=400
# [CV 5/5; 106/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=400;, score=0.440 total time= 2.4min
# [CV 1/5; 107/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=500
# [CV 1/5; 107/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=500;, score=0.495 total time=183.9min
# [CV 2/5; 107/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=500
# [CV 2/5; 107/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=500;, score=0.511 total time= 2.3min
# [CV 3/5; 107/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=500
# [CV 3/5; 107/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=500;, score=0.495 total time= 2.5min
# [CV 4/5; 107/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=500
# [CV 4/5; 107/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=500;, score=0.507 total time= 2.3min
# [CV 5/5; 107/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=500
# [CV 5/5; 107/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=500;, score=0.508 total time= 2.3min
# [CV 1/5; 108/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=600
# [CV 1/5; 108/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=600;, score=0.553 total time= 3.3min
# [CV 2/5; 108/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=600
# [CV 2/5; 108/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=600;, score=0.568 total time= 3.4min
# [CV 3/5; 108/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=600
# [CV 3/5; 108/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=600;, score=0.552 total time= 3.4min
# [CV 4/5; 108/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=600
# [CV 4/5; 108/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=600;, score=0.565 total time= 3.3min
# [CV 5/5; 108/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=600
# [CV 5/5; 108/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=8, n_estimators=600;, score=0.564 total time= 3.3min
# [CV 1/5; 109/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=10, n_estimators=200
# [CV 1/5; 109/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=10, n_estimators=200;, score=0.250 total time=  30.9s
# [CV 2/5; 109/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=10, n_estimators=200
# [CV 2/5; 109/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=10, n_estimators=200;, score=0.267 total time=  25.6s
# [CV 3/5; 109/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=10, n_estimators=200
# [CV 3/5; 109/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=10, n_estimators=200;, score=0.252 total time=  29.6s
# [CV 4/5; 109/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=10, n_estimators=200
# [CV 4/5; 109/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=10, n_estimators=200;, score=0.260 total time=  26.0s
# [CV 5/5; 109/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=10, n_estimators=200
# [CV 5/5; 109/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=10, n_estimators=200;, score=0.264 total time=  30.4s
# [CV 1/5; 110/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=10, n_estimators=400
# [CV 1/5; 110/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=10, n_estimators=400;, score=0.430 total time=78.1min
# [CV 2/5; 110/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=10, n_estimators=400
# [CV 2/5; 110/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=10, n_estimators=400;, score=0.449 total time= 1.6min
# [CV 3/5; 110/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=10, n_estimators=400
# [CV 3/5; 110/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=10, n_estimators=400;, score=0.435 total time= 1.6min
# [CV 4/5; 110/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=10, n_estimators=400
# [CV 4/5; 110/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=10, n_estimators=400;, score=0.440 total time= 1.7min
# [CV 5/5; 110/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=10, n_estimators=400
# [CV 5/5; 110/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=10, n_estimators=400;, score=0.446 total time= 1.6min
# [CV 1/5; 111/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=10, n_estimators=500
# [CV 1/5; 111/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=10, n_estimators=500;, score=0.497 total time= 2.6min
# [CV 2/5; 111/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=10, n_estimators=500
# [CV 2/5; 111/288] END booster=dart, eta=0.001, gamma=0.0, max_depth=10, n_estimators=500;, score=0.518 total time= 2.6min
# [CV 3/5; 111/288] START booster=dart, eta=0.001, gamma=0.0, max_depth=10, n_estimators=500

# %%
GCV.best_params_

# %%
Final Regression Model
Final_mod =  XGBRegressor(n_estimators=100 , booster= 'dart', eta= 0.1, max_depth= 10, gamma= 0.0 )
Final_mod.fit(X_train,Y_train)
y_pred=Final_mod.predict(X_test)
print('\n')                                        
print('\033[1m'+' Error in Final Model :' +'\033[0m')
print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
print('Mean squared error :', mean_squared_error(Y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
print('\n')
print('\033[1m'+' R2 Score of Final Model :'+'\033[0m')
print(r2_score(Y_test,y_pred)) 
print('\n')

# %%
plt.figure(figsize=(20,9))
y_pred=Final_mod.predict(X_test)
sns.swarmplot(Y_test.round(2), y_pred)
print('\033[1m'+' True Values Vs Predicted Value plot :' +'\033[0m')
plt.xlabel('True Values' , fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.tight_layout()

# %%
#Final Regression Saving Model
import joblib
joblib.dump(Final_mod,'Next_Tmax_Forecast_Final.pkl')

# %%
Standard Scaling
# Splitting data in target and dependent feature
X = df.drop(['Next_Tmin'], axis =1)
Y = df['Next_Tmin']
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %%
#Prediction According Final Regression Model
# Loading the saved model
Model = joblib.load("Next_Tmax_Forecast_Final.pkl")

# prediction  DataFrame
actual = np.array(Y_test)
predicted = np.array(Model.predict(X_test))
df_Predicted = pd.DataFrame({"Actual Values":actual,"Predicted Values":predicted},index= range(len(actual)))
df_Predicted

# %%
#Machine Learning Model Building For Next_Tmin
#Standard Scaling
# Splitting data in target and dependent feature
X = df.drop(['Next_Tmin'], axis =1)
Y = df['Next_Tmin']
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=42, test_size=.33)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)

# %%
#Finding best Random state
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
maxR2_score=0
maxRS=0
for i in range(1,500):
    X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=i, test_size=.33)
    lin_reg=LinearRegression()
    lin_reg.fit(X_train,Y_train)
    y_pred=lin_reg.predict(X_test)
    R2=r2_score(Y_test,y_pred)
    if R2>maxR2_score:
        maxR2_score=R2
        maxRS=i
print('Best R2 Score is', maxR2_score ,'on Random_state', maxRS)

# %%
Linear Regression Base Model
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=43, test_size=.33)
lin_reg=LinearRegression()
lin_reg.fit(X_train,Y_train)
lin_reg.score(X_train,Y_train)
y_pred=lin_reg.predict(X_test)
print('\033[1m'+'Predicted Wins:'+'\033[0m\n',y_pred)
print('\n')
print('\033[1m'+'Actual Wins:'+'\033[0m\n',Y_test)

# %%
Linear Regression Evaluation Matrix
print('\033[1m'+' Error :'+'\033[0m')
print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
print('Mean squared error :', mean_squared_error(Y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
print('\n')
from sklearn.metrics import r2_score
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(Y_test,y_pred,multioutput='variance_weighted'))

# %%
# Cross Validation
from sklearn.model_selection import cross_val_score
score = cross_val_score(lin_reg, X_scale, Y, cv =3)
print('\033[1m'+'Cross Validation Score :',lin_reg,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())

# %% [markdown]
# Applying other ML Models

# %%
rf = RandomForestRegressor()
dtc = DecisionTreeRegressor()
XT = ExtraTreesRegressor()
BR = BaggingRegressor()
adb=AdaBoostRegressor()
gradb=GradientBoostingRegressor()
xgb=XGBRegressor()
model = [rf,XT,dtc,adb,gradb,xgb]

for m in model:
    m.fit(X_train,Y_train)
    m.score(X_train,Y_train)
    y_pred = m.predict(X_test)
    print('\n')                                        
    print('\033[1m'+' Error of ', m, ':' +'\033[0m')
    print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
    print('Mean squared error :', mean_squared_error(Y_test,y_pred))
    print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
    print('\n')

    print('\033[1m'+' R2 Score :'+'\033[0m')
    print(r2_score(Y_test,y_pred)) 
    print('================================================================')

# %%
# Cross Validation
model = [rf,XT,dtc,adb,gradb,xgb]

for m in model:
    score = cross_val_score(m, X_scale, Y, cv =5)
    print('\n')
    print('\033[1m'+'Cross Validation Score :',m,":"+'\033[0m\n')
    print("Mean CV Score :",score.mean())
    print('==============================================================================================================')

# %%
Hyper Parameter Tuning : GridSearchCV
from sklearn.model_selection import GridSearchCV
parameter = {'n_estimators':[50,75,100],'gamma':np.arange(0,0.2,0.1),
              'booster' : ['gbtree','dart','gblinear'], 'max_depth':[4,6,8,10],
              'eta' : [0.001, 0.01, 0.1] }
GCV = GridSearchCV(XGBRegressor(),parameter,verbose =10)
GCV.fit(X_train,Y_train)
GCV.best_params_

# %%
Final Regression Model For Next_Tmin
Final_mod =  XGBRegressor(n_estimators=100 , booster= 'dart', eta= 0.1, max_depth= 8, gamma= 0.0 )
Final_mod.fit(X_train,Y_train)
y_pred=Final_mod.predict(X_test)
print('\n')                                        
print('\033[1m'+' Error in Final Model :' +'\033[0m')
print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
print('Mean squared error :', mean_squared_error(Y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
print('\n')
print('\033[1m'+' R2 Score of Final Model :'+'\033[0m')
print(r2_score(Y_test,y_pred)) 
print('\n')

# %%
plt.figure(figsize=(12,7))
y_pred=Final_mod.predict(X_test)
sns.swarmplot(Y_test.round(2), y_pred)
print('\033[1m'+' True Values Vs Predicted Value plot :' +'\033[0m')
plt.xlabel('True Values' , fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.tight_layout()

# %%
#Saving Final Regression Model For Next_Tmin
import joblib
joblib.dump(Final_mod,'Next_Tmin_Forecast_Final.pkl')

# %%
Prediction According Final Regression Model For Next_Tmin
# Loading the saved model
Model = joblib.load("Next_Tmin_Forecast_Final.pkl")

# prediction  DataFrame
actual = np.array(Y_test)
predicted = np.array(Model.predict(X_test))
df_Predicted = pd.DataFrame({"Actual Values":actual,"Predicted Values":predicted},index= range(len(actual)))
df_Predicted
